# %% [markdown]
# <a href="https://colab.research.google.com/github/Bikramjit08/MACHINE_LEARNING/blob/main/data_processing_flats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df= pd.read_csv('flats.csv')
df.head()
# Out:
#                      property_name  \
# 0     2 BHK Flat in Krishna Colony
# 1        2 BHK Flat in Ashok Vihar
# 2              2 BHK Flat in Sohna
# 3  2 BHK Flat in Sector 61 Gurgaon
# 4  2 BHK Flat in Sector 92 Gurgaon
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...  Tulsiani Easy in Homes
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...     Smart World Orchard
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...        Parkwood Westend
#
#         price             area                            areaWithType  \
# 0      45 Lac   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)
# 1      50 Lac   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)
# ...

# %%
# shape
df.shape
# Out:
# (3028, 20)

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3028 non-null   object
#  1   link             3028 non-null   object
#  2   society          3027 non-null   object
#  3   price            3008 non-null   object
#  4   area             3015 non-null   object
#  5   areaWithType     3009 non-null   object
#  6   bedRoom          3009 non-null   object
#  7   bathroom         3009 non-null   object
#  8   balcony          3009 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3003 non-null   object
#  11  floorNum         3007 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3008 non-null   object
#  14  nearbyLocations  2914 non-null   object
#  15  description      3009 non-null   object
# ...

# %%
# check for missing value
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                20
# area                 13
# areaWithType         19
# bedRoom              19
# bathroom             19
# balcony              19
# additionalRoom     1333
# address              25
# floorNum             21
# facing              900
# agePossession        20
# nearbyLocations     114
# description          19
# furnishDetails      824
# features            433
# rating              351
# property_id          19
# dtype: int64

# %%
df.drop(columns=['link','property_id'],inplace=True)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# rename columns
df.rename(columns={'area':'price_per_sqft'},inplace=True)
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %% [markdown]
# # SOCIETY **COLUMN** ⚛

# %%
# society
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                                     73
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            39
# Signature Global Park4.0 ★                           36
# Shree Vardhman Victoria3.8 ★                         35
# Tulip Violet4.2 ★                                    33
# Emaar MGF Emerald Floors Premier3.8 ★                32
# Smart World Orchard                                  32
# Smart World Gems                                     32
# DLF The Ultima4.0 ★                                  31
# Paras Dews                                           31
# DLF Regal Gardens3.9 ★                               30
# M3M Woodshire4.0 ★                                   29
# Shree Vardhman Flora3.8 ★                            29
# Signature Global Solera3.7 ★                         28
# La Vida by Tata Housing                              28
# Godrej Nature Plus                                   27
# ...

# %%
df['society'].value_counts().shape
# Out:
# (639,)

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].value_counts().shape
# Out:
# (605,)

# %%
df['society'].value_counts()
# Out:
# society
# tulip violet                                     75
# ss the leaf                                      74
# shapoorji pallonji joyville gurugram             45
# dlf new town heights                             38
# signature global park                            36
# shree vardhman victoria                          35
# smart world gems                                 32
# emaar mgf emerald floors premier                 32
# smart world orchard                              32
# paras dews                                       31
# dlf the ultima                                   31
# m3m woodshire                                    30
# dlf regal gardens                                30
# shree vardhman flora                             29
# signature global solera                          28
# la vida by tata housing                          28
# godrej nature plus                               27
# emaar gurgaon greens                             25
# ...

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %% [markdown]
# # **PRICE COLUMN :**

# %%
df['price'].head()
# Out:
# 0        45 Lac
# 1        50 Lac
# 2        40 Lac
# 3    1.47 Crore
# 4        70 Lac
# Name: price, dtype: object

# %%
df['price'].shape
# Out:
# (3028,)

# %%
df = df.dropna(subset=['price']) # Drop rows where 'price' is NaN

# %%
df['price'].shape
# Out:
# (3008,)

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.5 Crore           59
# 1.2 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 75 Lac              38
# 1.65 Crore          38
# 1.8 Crore           37
# 1.7 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 1.45 Crore          31
# 85 Lac              31
# 1.05 Crore          30
# 2.5 Crore           29
# 60 Lac              29
# 40 Lac              29
# 2.1 Crore           26
# 45 Lac              26
# 65 Lac              25
# 35 Lac              23
# 1.85 Crore          23
# 2.35 Crore          23
# 3 Crore             22
# 70 Lac              21
# 2.25 Crore          20
# 55 Lac              20
# ...

# %%
df[df['price'] == 'Price on Request']
# Out:
#                          property_name                    society  \
# 25      5 BHK Flat in Sector 1 Gurgaon  the new people apartments
# 1645   4 BHK Flat in Sector 50 Gurgaon                ss hibiscus
# 1973   1 BHK Flat in Sector 31 Gurgaon            raheja atlantis
# 2055   2 BHK Flat in Sector 79 Gurgaon         supertech araville
# 2358  2 BHK Flat in Sector 37D Gurgaon            the millennia 2
# 2523  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2550      3 BHK Flat in Sector-2 Sohna         supertech hilltown
# 2641  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2960  3 BHK Flat in Sector 104 Gurgaon              godrej summit
# 2973         4 BHK Flat in Gwal Pahari     krrish provence estate
# 2974   4 BHK Flat in Sector 95 Gurgaon    sidhartha ncr one phase
#
#                  price price_per_sqft  \
# 25    Price on Request            NaN
# 1645  Price on Request            NaN
# 1973  Price on Request            NaN
# ...

# %%
df = df[df['price'] != 'Price on Request']

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
def treat_price(x):
    if isinstance(x, float): # Check if x is already a float
        return x
    else:
        try: # Handle potential IndexError
            x = x.split()
            if len(x) > 1 and x[1] == 'Lac':
                return round(float(x[0])/100,2)
            elif len(x) > 0:  # Check if x has at least one element
                return round(float(x[0]),2)
            else:
                return np.nan # Or handle empty price as needed
        except (ValueError, TypeError): # Handle non-numeric price
            return np.nan # Or handle invalid price as needed

# %%
df['price'] = df['price'].apply(treat_price)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %% [markdown]
# ## price_per_sqft

# %%
df['price_per_sqft'].shape
# Out:
# (2997,)

# %%
df['price_per_sqft'].head()
# Out:
# 0     ₹ 5,000/sq.ft.
# 1     ₹ 7,692/sq.ft.
# 2     ₹ 6,722/sq.ft.
# 3    ₹ 12,250/sq.ft.
# 4     ₹ 5,204/sq.ft.
# Name: price_per_sqft, dtype: object

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 5,000/sq.ft.      13
# ₹ 6,666/sq.ft.      13
# ₹ 7,500/sq.ft.      12
# ₹ 8,333/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 12,000/sq.ft.      8
# ₹ 7,000/sq.ft.       8
# ₹ 9,000/sq.ft.       7
# ₹ 9,230/sq.ft.       6
# ₹ 11,111/sq.ft.      6
# ₹ 8,928/sq.ft.       6
# ₹ 6,578/sq.ft.       6
# ₹ 5,500/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 4,666/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 16,000/sq.ft.      5
# ₹ 8,571/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 7,641/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 7,142/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 8,888/sq.ft.       5
# ₹ 7,692/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 5,384/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 6,500/sq.ft.       5
# ₹ 8,043/sq.ft.       4
# ₹ 8,784/sq.ft.       4
# ₹ 15,000/sq.ft.      4
# ...

# %%
df['price_per_sqft'].str.contains('area').value_counts()
# Out:
# price_per_sqft
# False    2996
# True        1
# Name: count, dtype: int64

# %%
df = df[~df['price_per_sqft'].str.contains('area')]

# %%
df['price_per_sqft']=df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹', '').str.replace(',', '').str.strip().astype(float)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# ...

# %% [markdown]
# # **BEDROOM**

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 3 Bedrooms    1437
# 2 Bedrooms     943
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: count, dtype: int64

# %%
df['bedRoom'].str.split(' ').str.get(0).astype(int)
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
# 5       2
# 6       3
# 7       3
# 8       2
# 9       3
# 10      2
# 11      2
# 12      3
# 13      2
# 14      2
# 15      4
# 16      1
# 17      2
# 19      3
# 20      2
# 21      3
# 22      2
# 23      3
# 24      3
# 26      2
# 27      3
# 28      3
# 29      2
# 30      2
# 31      2
# 32      4
# 33      2
# 34      3
# 35      2
# 36      2
# 37      3
# 38      2
# 39      2
# 40      3
# 41      2
# 42      3
# 43      4
# 44      2
# 45      3
# 46      4
# 47      2
# 48      3
# 49      3
# 50      3
# 51      2
# 52      2
# 53      3
# 54      2
# 55      4
# 56      1
# 57      1
# 58      3
# 59      2
# 60      2
# 61      2
# 62      4
# 63      2
# 64      3
# 65      4
# 66      3
# 67      3
# 68      2
# 69      2
# 70      2
# 71      3
# 72      2
# 73      2
# 74      2
# 75      3
# 76      2
# 77      2
# 78      3
# 79      3
# 80      3
# 81      3
# 82      2
# 83      5
# 84      2
# ...

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype(int)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType  bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)        2
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)        2
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)        2
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)        2
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)        2
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['bathroom'].isnull().value_counts()
# Out:
# bathroom
# False    2996
# Name: count, dtype: int64

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype(int)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)        2         2
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)        2         2
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)        2         2
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)        2         2
#
#        balcony additionalRoom                              address  \
# ...

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3 Balconies     973
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: count, dtype: int64

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)        2         2
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)        2         2
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)        2         2
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
# additionalRoom
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Study Room,Pooja Room                              8
# Servant Room,Study Room                            8
# ...

# %%
df['additionalRoom'].value_counts().shape
# Out:
# (49,)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 1304

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# <ipython-input-159-37c81a970354>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)        2         2
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)        2         2
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)        2         2
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %% [markdown]
# # **Floor Num**

# %%
df['floorNum'].head()
# Out:
# 0      4th   of 4 Floors
# 1      1st   of 3 Floors
# 2    12nd   of 14 Floors
# 3      2nd   of 4 Floors
# 4      5th   of 8 Floors
# Name: floorNum, dtype: object

# %%
df['floorNum'].isnull().sum()
# Out:
# 2

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).str.replace('Basement','-1').str.replace('Lower','0').replace('Ground','0').str.extract(r'(\d+)')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)        2         2
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)        2         2
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)        2         2
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# ...

# %% [markdown]
# # FACING **COLUMN**

# %%
df['facing'].isnull().sum()
# Out:
# 874

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-167-e6ba103970bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            874
# North-East    505
# East          489
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   property_type    2996 non-null   object
#  2   society          2996 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2996 non-null   object
#  7   bedRoom          2996 non-null   int64
#  8   bathroom         2996 non-null   int64
#  9   balcony          2996 non-null   object
#  10  additionalRoom   2996 non-null   object
#  11  address          2990 non-null   object
#  12  floorNum         2994 non-null   object
#  13  facing           2996 non-null   object
#  14  agePossession    2995 non-null   object
#  15  nearbyLocations  2905 non-null   object
#  16  description      2996 non-null   object
# ...

# %%
df.shape
# Out:
# (2996, 20)

# %%
df.to_csv('flats_cleaned.csv',index=False)
